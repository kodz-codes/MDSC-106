# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#importing the pandas, seaborn, matplotlib libraries
#from sklearn importing the datasets
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
#The data here is normalised data
data_dictionary = datasets.load_diabetes(as_frame = True)
dataframe = data_dictionary['data']
dataframe
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
data_dictionary['target']
# Out:
# 0      151.0
# 1       75.0
# 2      141.0
# 3      206.0
# 4      135.0
#        ...
# 437    178.0
# 438    104.0
# 439    132.0
# 440    220.0
# 441     57.0
# Name: target, Length: 442, dtype: float64

# %%
# Dataset can be downloaded from this source
# https://www.kaggle.com/code/antoniofurioso/predict-diabetes-machine-learning-project
#The data being downloaded here is not a normalised data
df = pd.read_table(r'/content/drive/MyDrive/Colab Notebooks/MDSC-106/diabetes_data.txt')
df = df.rename(columns={'AGE': 'age', 'SEX': 'sex', 'BMI':'bmi', 'BP':'bp','S1':'s1', 'S2':'s2', 'S3':'s3', 'S4':'s4', 'S5':'s5', 'S6':'s6', 'Y':'target'})
df.head()
# Out:
#    age  sex   bmi     bp   s1     s2    s3   s4      s5  s6  target
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87     151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69      75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85     141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89     206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80     135

# %% [markdown]
# perform below mentioned dataframe operations on the data: -
# *   add 2 synthetic columns with column name 'Name of Patient', 'Patient aadhaar number'
#
# *  write meaningful data to those columns ( based on real life examples )
#
# *  check for null values in the dataframe
# * check and display the the count of null values in the dataframe under each column name
#
# *  try to modilfy the data for below cells with null values - row 1, column 5 - row 2, column 3 - row 5, column 11 - row 96, column 5 - row 1, column 1 - now display the dataframe and observe the null values associated to each column
#
# *  display the count of null values in the datframe now ( i.e. after adding columns, modifying under synthetic new columns too )
# *  drop one of the column you have created i.e. 'Name of Patient' - fill the null values in column 1 i.e. 'Age' with meaningful data based on the other values available in that column

# %%
df['Name_of_patient'], df['Patient_Aadhaar_number'] = None, None
df
# Out:
#      age  sex   bmi      bp   s1     s2    s3    s4      s5   s6  target  \
# 0     59    2  32.1  101.00  157   93.2  38.0  4.00  4.8598   87     151
# 1     48    1  21.6   87.00  183  103.2  70.0  3.00  3.8918   69      75
# 2     72    2  30.5   93.00  156   93.6  41.0  4.00  4.6728   85     141
# 3     24    1  25.3   84.00  198  131.4  40.0  5.00  4.8903   89     206
# 4     50    1  23.0  101.00  192  125.4  52.0  4.00  4.2905   80     135
# ..   ...  ...   ...     ...  ...    ...   ...   ...     ...  ...     ...
# 437   60    2  28.2  112.00  185  113.8  42.0  4.00  4.9836   93     178
# 438   47    2  24.9   75.00  225  166.0  42.0  5.00  4.4427  102     104
# 439   60    2  24.9   99.67  162  106.6  43.0  3.77  4.1271   95     132
# 440   36    1  30.0   95.00  201  125.2  42.0  4.79  5.1299   85     220
# 441   36    1  19.6   71.00  250  133.2  97.0  3.00  4.5951   92      57
#
#     Name_of_patient Patient_Aadhaar_number
# 0              None                   None
# ...

# %%
df.isnull()
# Out:
#        age    sex    bmi     bp     s1     s2     s3     s4     s5     s6  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 437  False  False  False  False  False  False  False  False  False  False
# 438  False  False  False  False  False  False  False  False  False  False
# 439  False  False  False  False  False  False  False  False  False  False
# 440  False  False  False  False  False  False  False  False  False  False
# 441  False  False  False  False  False  False  False  False  False  False
#
#      target  Name_of_patient  Patient_Aadhaar_number
# ...

# %%
import random

names_list = ['Abhinay','Jaswath','Swaroop','Ayush','Chetri','Sumiran','Pankaj','Bhargav']

for i in range(0,442):
  temp_variable = random.choice(names_list)
  temp_aadhaar = random.randint(10000000000,100000000000)
  # print(variable)
  df.loc[i,'Name_of_patient'], df.loc[i,'Patient_Aadhaar_number'] = temp_variable, temp_aadhaar
  # print(df['Name_of_patient'])

df
# Out:
#      age  sex   bmi      bp   s1     s2    s3    s4      s5   s6  target  \
# 0     59    2  32.1  101.00  157   93.2  38.0  4.00  4.8598   87     151
# 1     48    1  21.6   87.00  183  103.2  70.0  3.00  3.8918   69      75
# 2     72    2  30.5   93.00  156   93.6  41.0  4.00  4.6728   85     141
# 3     24    1  25.3   84.00  198  131.4  40.0  5.00  4.8903   89     206
# 4     50    1  23.0  101.00  192  125.4  52.0  4.00  4.2905   80     135
# ..   ...  ...   ...     ...  ...    ...   ...   ...     ...  ...     ...
# 437   60    2  28.2  112.00  185  113.8  42.0  4.00  4.9836   93     178
# 438   47    2  24.9   75.00  225  166.0  42.0  5.00  4.4427  102     104
# 439   60    2  24.9   99.67  162  106.6  43.0  3.77  4.1271   95     132
# 440   36    1  30.0   95.00  201  125.2  42.0  4.79  5.1299   85     220
# 441   36    1  19.6   71.00  250  133.2  97.0  3.00  4.5951   92      57
#
#     Name_of_patient Patient_Aadhaar_number
# 0           Abhinay            22786849127
# ...

# %%
plt.figure(figsize=(20, 7)) # The figure() sttribute of matplotlib can be used when we want to change the default size of the plot.
# plt.show()

plt.subplot(1,4,1) # This help us to draw a subplot in a plot indicating the one row, four columns, and the index of the subplot respectively
#1st row, with 4 columns and 1st subplot
sns.histplot(df['age'], kde = True,color='r')
plt.title('Histogram')

# scatterplot
plt.subplot(1, 4, 2)
plt.scatter(df['age'],df['bp'],color = 'g')
plt.title('Scatterplot')

# boxplot
plt.subplot(1, 4, 3)
sns.boxplot(y=df['target'],color = 'b')
plt.title('Boxplot')

# barplot
plt.subplot(1, 4, 4)
sns.barplot(x='target', y = 'bmi', data = df)
plt.title('Barplot')

plt.show()

# %%
plt.hist(df['age']) # plotting the histogram of the age
# Out:
# (array([19., 28., 47., 53., 55., 85., 69., 47., 33.,  6.]),
#  array([19., 25., 31., 37., 43., 49., 55., 61., 67., 73., 79.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['age'], bins=9) # plotting the histogram according to the number of bins of our choice
# Out:
# (array([24., 34., 53., 54., 92., 72., 68., 39.,  6.]),
#  array([19.        , 25.66666667, 32.33333333, 39.        , 45.66666667,
#         52.33333333, 59.        , 65.66666667, 72.33333333, 79.        ]),
#  <BarContainer object of 9 artists>)

# %%
df['age'].min()
# Out:
# 19

# %%
df['age'].max()
# Out:
# 79

# %%
# more specific about the size of bins that you have, you can define them entirely. For example, if you wanted your bins to fall in five year increments
plt.hist(df['age'], bins=[0,5,10,15,20,25,35,40,45,50])
# Out:
# (array([ 0.,  0.,  0.,  3., 16., 59., 39., 44., 66.]),
#  array([ 0.,  5., 10., 15., 20., 25., 35., 40., 45., 50.]),
#  <BarContainer object of 9 artists>)

# %%
#
plt.hist(df['age'], log=True)
# Out:
# (array([19., 28., 47., 53., 55., 85., 69., 47., 33.,  6.]),
#  array([19., 25., 31., 37., 43., 49., 55., 61., 67., 73., 79.]),
#  <BarContainer object of 10 artists>)

# %%
# To change the alignment and color of the histogram
plt.hist(df['age'], bins = 9, align = 'right', color = 'purple', edgecolor = 'yellow')
# Out:
# (array([24., 34., 53., 54., 92., 72., 68., 39.,  6.]),
#  array([19.        , 25.66666667, 32.33333333, 39.        , 45.66666667,
#         52.33333333, 59.        , 65.66666667, 72.33333333, 79.        ]),
#  <BarContainer object of 9 artists>)

# %%
# Pandas histograms can be applied to the dataframe directly, using the hist function
df.hist()
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>,
#         <Axes: title={'center': 'bmi'}>],
#        [<Axes: title={'center': 'bp'}>, <Axes: title={'center': 's1'}>,
#         <Axes: title={'center': 's2'}>],
#        [<Axes: title={'center': 's3'}>, <Axes: title={'center': 's4'}>,
#         <Axes: title={'center': 's5'}>],
#        [<Axes: title={'center': 's6'}>,
#         <Axes: title={'center': 'target'}>, <Axes: >]], dtype=object)

# %%
# This just remove the grid from the plot, and if there are more bins than 9, it wil
df.hist(grid = False, bins = 9)
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>,
#         <Axes: title={'center': 'bmi'}>],
#        [<Axes: title={'center': 'bp'}>, <Axes: title={'center': 's1'}>,
#         <Axes: title={'center': 's2'}>],
#        [<Axes: title={'center': 's3'}>, <Axes: title={'center': 's4'}>,
#         <Axes: title={'center': 's5'}>],
#        [<Axes: title={'center': 's6'}>,
#         <Axes: title={'center': 'target'}>, <Axes: >]], dtype=object)

# %%
# adding titles, axis labels for the plots
df['age'].hist(grid = False, bins = 9, color = 'magenta')
plt.xlabel("Age of Patients")
plt.ylabel(" # (cardinality or count) of patients of that age")
plt.title("Age Distribution in a histogram plot")
# Out:
# Text(0.5, 1.0, 'Age Distribution in a histogram plot')

# %% [markdown]
# # **Bar plots**

# %%
x = df['age']
y = df['target']
# plt.bar(df['age'], df['target'])
plt.bar(x,y)
plt.show()

# %%
# The bar() plot and barh() plot - the difference between them is it just plots the bar plot horizontally increasing.
plt.barh(x,y)
# plt.barh(df['age'],df['target'])
plt.show()

# %%
# plotting a bax plot by  changing the deafult color.
plt.bar(x,y, color = 'darkgreen')
# plt.bar(df['age'],df['target'], color = 'darkgreen')
plt.show()

# We can send hexadecimal or any other color format as the argument for the color of the graph
plt.barh(x,y, color = '#4CAF50')
plt.show()

# %%
# The bar() plot takes the keyword argument width to set the width of the each bar being plotted.
plt.bar(x,y, width = 0.1)
# Out:
# <BarContainer object of 442 artists>

# %%
# The barh() takes the keyword argument height to set the height of each bar
plt.barh(x,y, height = 1)
plt.show()

# the argument width in bar() plot is same as the argument height in the barh() plot.
# why height is associated to barh() function only ?
# it eindicates the height of each bar in the barh() function which is similar to width argument of bar() function.

# %%
# Documentation given here
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html

# %% [markdown]
# # **Stacked bar plot :-**
#
# ## **Approach:**
#
# ### **Import Library (Matplotlib)**
# ### **Import / create data.**
# ### **Plot the bars in the stack manner.**

# %%
# importing package
import matplotlib.pyplot as plt

# create data
x = ['A', 'B', 'C', 'D']
y1 = [10, 20, 10, 30]
y2 = [20, 25, 15, 25]

# plot bars in stack manner
plt.bar(x, y1, color='yellow', edgecolor = 'black')
plt.bar(x, y2, bottom=y1, color='purple', edgecolor = 'black')
plt.show()

# %%
# importing package
import matplotlib.pyplot as plt
import numpy as np

# create data
x = ['A', 'B', 'C', 'D']
y1 = np.array([10, 20, 10, 30])
y2 = np.array([20, 25, 15, 25])
y3 = np.array([12, 15, 19, 6])
y4 = np.array([10, 29, 13, 19])
print(x,y1,y2,y3,y4)

# plot bars in stack manner
plt.bar(x, y1, color='r')
plt.bar(x, y2, bottom=y1, color='b')
plt.bar(x, y3, bottom=y1+y2, color='y')
plt.bar(x, y4, bottom=y1+y2+y3, color='g')
plt.xlabel("Teams")
plt.ylabel("Score")
plt.legend(["Round 1", "Round 2", "Round 3", "Round 4"])
plt.title("Scores by Teams in 4 Rounds")
plt.show()
# Out:
# ['A', 'B', 'C', 'D'] [10 20 10 30] [20 25 15 25] [12 15 19  6] [10 29 13 19]

# %%
# importing package
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# create data
df = pd.DataFrame([['A', 10, 20, 10, 26],
                   ['B', 20, 25, 15, 21],
                   ['C', 12, 15, 19, 6],
                   ['D', 10, 18, 11, 19]],columns=['Team', 'Round 1', 'Round 2', 'Round 3', 'Round 4'])
# view data
print(df)

# plot data in stack manner of bar type
df.plot(x='Team', kind='bar', stacked=True,
        title='Stacked Bar Graph by dataframe')
plt.show()
# Out:
#   Team  Round 1  Round 2  Round 3  Round 4
# 0    A       10       20       10       26
# 1    B       20       25       15       21
# 2    C       12       15       19        6
# 3    D       10       18       11       19

# %% [markdown]
# # **BoxPlots :-**
# ![image.png](data:image/png;base64,...)
#
# *   Box plots summarize data values** **bold text**
# *   In the box plot, a box is created from the first quartile to the third quartile.
# *   A vertical line is also there which goes through the box at the median.
# *   Here x-axis denotes the data to be plotted while the y-axis shows the frequency distribution.
# *   Display properties like minimum, first quartile, median, third quartile, and maximum
# *   Also known as Whisker plots
#
# ## **Procedure for constructing a Box Plot :-**
# 1. Create a Box from the first quartile to third quartile
# 2. Represent data on the X-axis.
# 3. Show frequency distribution on Y-axis.
# 4. Include a vertical line at the median.
#
#
# * The "notch = True" attribute creates the notch format to the box plot.
#
# * "patch_artist = True" fills the boxplot with colors.
#
# * we can set different colors to different boxes.
#
# * The "vert = 0" attribute creates horizontal box plot.
#
# * labels takes same dimensions as the number data sets.

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
# Creating dataset
np.random.seed(10)
np

data_1 = np.random.normal(100, 10, 200)
data_2 = np.random.normal(90, 20, 200)
data_3 = np.random.normal(80, 30, 200)
data_4 = np.random.normal(70, 40, 200)
data = [data_1, data_2, data_3, data_4]

fig = plt.figure(figsize =(8, 4))
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
# Creating plot
bp = ax.boxplot(data)

# show plot
plt.show()
